# %% [markdown]
# ### It tell how well the model is performing by measuring the difference between the predicted output and the actual target values.
#
# ### The goal during training is to minimize this loss, effectively improving the model's ability to make accurate predictions. Different tasks and problems may require different loss functions. Here are some commonly used loss functions in deep learning:
# w one probability distribution diverges from a second, expected probability distribution. It is often used in tasks involving probability distributions, such as in generative models like Variational Autoencoders (VAEs).

# %% [raw]
# # Loss Funcation is for single data
# # cost Funcation is for batch data

# %% [markdown]
# # MSE ()

# %% [markdown]
# ![image.png](attachment:e783acb6-e31c-44c9-955b-bc9b5a763b90.png)

# %%
# no local minima in mse 
# may be local minima in mae

# %% [markdown]
# ![image.png](attachment:fd7de912-80dd-4ee9-807a-88a983d3c622.png)

# %% [markdown]
# # Huber lose

# %% [markdown]
# ![image.png](attachment:3c3b7993-39dd-43a0-a63a-1fd838b54ec0.png)
